# %% [markdown]
# <a href="https://colab.research.google.com/github/AdwaithaV/QuantumOP/blob/main/Bell_states.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install qiskit_aer
# !pip install pylatexenc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 MB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 31.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=f8c43bf75c11aa81dc6ae38b9a238fc6f3ce96be770ef0c1542cc4b86f9ffffe
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# ...

# %%
from qiskit import QuantumCircuit , transpile
from qiskit_aer import Aer
import matplotlib.pyplot as plt

qc=QuantumCircuit(2,2)

qc.h(0)
qc.cx(0,1)
qc.measure(0,0)
qc.measure(1,1)

qc.draw("mpl")

# %%
simulator=Aer.get_backend("qasm_simulator")
circ=transpile(qc,simulator)

job=simulator.run(circ,shots=2040)
res=job.result()

counts=res.get_counts()

print(counts)

plt.bar(counts.keys(),counts.values())

plt.title("Quantum circuit measurement results")
plt.xlabel("outcome")
plt.ylabel("frequency")

plt.show()
# Out:
# {'11': 1045, '00': 995}

# %%
from qiskit import QuantumCircuit,  transpile
from qiskit_aer import Aer
import matplotlib.pyplot as plt

qc=QuantumCircuit(2,2)

qc.h(0)
qc.z(1)
qc.cx(0,1)

qc.measure(0,0)

qc.measure(1,1)

qc.draw("mpl")

# %%
simulator=Aer.get_backend("qasm_simulator")

circ=transpile(qc,simulator)

job=simulator.run(circ,shots=2040)

res=job.result()

counts=res.get_counts()

print(counts)

plt.bar(counts.keys(),counts.values())

plt.title("Quantum circuit measurement results")

plt.xlabel("outcome")

plt.ylabel("frequency")

plt.show()
# Out:
# {'00': 1026, '11': 1014}

# %%
from qiskit import QuantumCircuit ,transpiler
from qiskit_aer import Aer
import matplotlib.pyplot as plt

qc=QuantumCircuit(2,2)

qc.h(0)
qc.cx(0,1)
qc.x(0)

qc.measure(0,0)
qc.measure(1,1)
qc.draw("mpl")

# %%
simulator=Aer.get_backend("qasm_simulator")
circ=transpile(qc,simulator)

job=simulator.run(circ,shots=1000)

res=job.result()

counts=res.get_counts()
print(counts)

plt.bar(counts.keys(),counts.values())

plt.title("QuantumCircuits measurement results")
plt.xlabel("outcome")
plt.ylabel("frequency")

plt.show()
# Out:
# {'10': 458, '01': 542}

# %%
from qiskit import QuantumCircuit ,transpiler
from qiskit_aer import Aer
import matplotlib.pyplot as plt

qc=QuantumCircuit(2,2)

qc.h(0)
qc.x(1)
qc.cx(0,1)


qc.measure(0,0)
qc.measure(1,1)
qc.draw("mpl")

# %%
simulator=Aer.get_backend("qasm_simulator")
circ=transpile(qc,simulator)

job=simulator.run(circ,shots=1000)

res=job.result()

counts=res.get_counts()
print(counts)

plt.bar(counts.keys(),counts.values())

plt.title("QuantumCircuits measurement results")
plt.xlabel("outcome")
plt.ylabel("frequency")

plt.show()
# Out:
# {'10': 502, '01': 498}

# %%
from qiskit import QuantumCircuit , transpiler
from qiskit_aer import Aer
import matplotlib.pyplot as plt

qc=QuantumCircuit(2,2)

qc.h(0)
qc.x(1)
qc.z(1)
qc.cx(0,1)

qc.measure(0,0)
qc.measure(1,1)

qc.draw("mpl")

# %%
simulator=Aer.get_backend("qasm_simulator")
circ=transpile(qc,simulator)

job=simulator.run(circ,shots=2040)

res=job.result()

counts=res.get_counts()

print(counts)

plt.bar(counts.keys(),counts.values())

plt.title("quantum circuit measurements")
plt.xlabel("outcome")
plt.ylabel("frequency")

plt.show()
# Out:
# {'10': 1029, '01': 1011}
